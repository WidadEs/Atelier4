# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer

# Charger les données à partir du fichier CSV
df = pd.read_csv('data.csv')

# Initialiser les outils de prétraitement NLTK
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Tokenisation
df['tokens'] = df['text'].apply(lambda x: word_tokenize(x))

# Lemmatisation
lemmatizer = WordNetLemmatizer()
df['lemmatized_tokens'] = df['tokens'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# Suppression des mots vides
stop_words = set(stopwords.words('arabic'))
df['filtered_tokens'] = df['lemmatized_tokens'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# Optionnel : Discrétisation si nécessaire

# Afficher un échantillon des données prétraitées
print(df[['text', 'filtered_tokens']].head())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 text  \
# 0  إسرائيل تصف قرار المدعي العام بـ "الفضيحة" وحم...
# 1  إسرائيل تعتزم توسيع الاجتياح العسكري لرفح، وال...
# 2  انقسام في إسرائيل على خطة إدارة غزة بعد الحرب،...
# 3  تيك توك و"الإنسان الأخير": لماذا أصبح التطبيق ...
# 4  اليوم العالمي للشاي: أكثر المشروبات استهلاكاً ...
#
#                                      filtered_tokens
# 0  [إسرائيل, تصف, قرار, المدعي, العام, بـ, ``, ال...
# 1  [إسرائيل, تعتزم, توسيع, الاجتياح, العسكري, لرف...
# 2  [انقسام, إسرائيل, خطة, إدارة, غزة, الحرب،, ونت...
# 3  [تيك, توك, '', الإنسان, الأخير, '', :, لماذا, ...
# 4  [اليوم, العالمي, للشاي, :, المشروبات, استهلاكا...

# %%
df
# Out:
#                                                  text  score  \
# 0   إسرائيل تصف قرار المدعي العام بـ "الفضيحة" وحم...      7
# 1   إسرائيل تعتزم توسيع الاجتياح العسكري لرفح، وال...      6
# 2   انقسام في إسرائيل على خطة إدارة غزة بعد الحرب،...     10
# 3   تيك توك و"الإنسان الأخير": لماذا أصبح التطبيق ...      2
# 4   اليوم العالمي للشاي: أكثر المشروبات استهلاكاً ...      1
# 5   ناريندرا مودي: عقد من الشعبية والاستقطاب السيا...      0
# 6   علاج جديد مبتكر قد يعالج الشلل الناتج عن كسر ف...      2
# 7   لماذا النسيان مفيد؟صدر الصورة،Getty ImagesArti...      2
# 8   لماذا يتمسك الفلسطينيون بالاعتراف الأممي بـ "د...      9
# 9   من تبريز إلى مشهد: ما خصوصية المدن التي تمرّ ب...      0
# 10  التعذيب الأبيض: من تزمامارت، إيفين، أبوغريب وغ...      3
# 11  محمد صلاح يلمح إلى البقاء في ليفربول بعد تعيين...      2
# 12  أوضح رئيسالمحكمة الجنائية الدوليةالسابق القاضي...      7
# 13  قال وزير الخارجية الأميركيأنتوني بلينكن-اليوم ...     10
# 14  أكدت صحيفة "واشنطن بوست" اليوم الثلاثاء أن إسر...      6
# 15  بوتين وشي: انتهاء علاقة الأقران الأندادصدر الص...      2
# 16  محكمة العدل الدولية تأمر إسرائيل بالوقف الفوري...      8
# 17  بي بي سي توثق فرحة أم بابنها الذي لُقب بأصغر ر...      3
# 18  تصاعد الخلاف بين نتنياهو والمؤسسة الأمنية الإس...     10
# 19  الصين تجري مناورات عسكرية "عقابية" حول تايوانص...      2
# 20  حرب غزة: هل تلتزم إسرائيل بقرار محكمة العدل ال...      9
# 21  إقبال كبير على جعة "أسامة بن لاغر" في حانة بري...      1
# 22  حرب الأجيال في ميانمار، الشباب ينتصر على جيش ا...      6
# 23  العثور على ملفات حساسة في غرفة نوم ترامب بعد ت...      1
# 24  السعودية: "لا سلام مع إسرائيل قبل ضمانات لحل ا...      7
# 25  أبرز حوادث الطيران التي لقيت فيها شخصيات معروف...      0
# 26  ردود فعل متباينة حول اتفاق حمدوك مع فصيلين مسل...      3
# 27  "كلما طال أمد الحرب، كلما زادت عزلة إسرائيل عن...      6
# 28  جدة بريطانية ثمانينية تصعد جبلاً في فرنسا على ...      6
# 29  قوات الدعم السريع في السودان تؤكد استعدادها فت...      3
# 30  علماء يتوصلون إلى حل للغز بناء أهرامات مصرصدر ...      3
# 31  الموناليزا: جيولوجية تحل لغز المكان الذي رُسمت...      0
# 32  بنوك مودي في الهند تنفق 400 مليار دولار ليفوز ...      0
# 33  "نحن بحاجة إلى معجزة": الاقتصادان الإسرائيلي و...      6
# 34  التضخم في تركيا: "نحن عالقون بين سداد بطاقة ال...      1
# 35  لماذا يعتبر الهواء النقي رفاهية لا يقدر الكثير...      2
# 36  هل يزعم الغرب أن الصين تنتج فائضا عن حاجتها بي...      1
# 37  قضية أموال "قذرة" بقيمة ملياري دولار تهز سنغاف...      0
# 38  كيف تُصدّر أوكرانيا حبوبها وما حجمها الآن؟صدر ...      2
# 39  شركة يابانية توقف إنتاج حفاضات الأطفال لتوفيره...      0
# 40  ماكدونالدز تسترد ملكية فروع مطاعمها في إسرائيل...      6
# 41  بريطانيا تشهد أكبر ارتفاع في معدل الفقر المدقع...      0
# 42  المحكمة العليا تقضي بعدم جواز قرار منع ترامب م...      4
# 43  كيف أثرت القيود المفروضة على العملة الأجنبية س...      1
# 44  ماذا نعرف عن حريق فالنسيا وأسبابه المحتملة؟صدر...      3
# 45  النكبة: ماذا حدث في 1948؟ ولماذا يحمل الفلسطين...      6
# 46  ماذا يعني تدخل مصر لدعم دعوى جنوب أفريقيا ضد إ...      8
# 47  "بمجرد دخولنا على المصابين والأطباء ترتفع معنو...      6
# 48  "إسرائيل ستدفع ثمن التردد في اتخاذ القرار في غ...      8
# 49  عائلات الرهائن الإسرائيليين تطالب بـ"صفقة فوري...      8
# 50  حماس تقول إن هجوم رفح "لن يكون نزهة"، ونتنياهو...      8
#
#                                                tokens  \
# 0   [إسرائيل, تصف, قرار, المدعي, العام, بـ, ``, ال...
# 1   [إسرائيل, تعتزم, توسيع, الاجتياح, العسكري, لرف...
# 2   [انقسام, في, إسرائيل, على, خطة, إدارة, غزة, بع...
# 3   [تيك, توك, و, '', الإنسان, الأخير, '', :, لماذ...
# 4   [اليوم, العالمي, للشاي, :, أكثر, المشروبات, اس...
# 5   [ناريندرا, مودي, :, عقد, من, الشعبية, والاستقط...
# 6   [علاج, جديد, مبتكر, قد, يعالج, الشلل, الناتج, ...
# 7   [لماذا, النسيان, مفيد؟صدر, الصورة،Getty, Image...
# 8   [لماذا, يتمسك, الفلسطينيون, بالاعتراف, الأممي,...
# 9   [من, تبريز, إلى, مشهد, :, ما, خصوصية, المدن, ا...
# 10  [التعذيب, الأبيض, :, من, تزمامارت،, إيفين،, أب...
# 11  [محمد, صلاح, يلمح, إلى, البقاء, في, ليفربول, ب...
# 12  [أوضح, رئيسالمحكمة, الجنائية, الدوليةالسابق, ا...
# 13  [قال, وزير, الخارجية, الأميركيأنتوني, بلينكن-ا...
# 14  [أكدت, صحيفة, ``, واشنطن, بوست, '', اليوم, الث...
# 15  [بوتين, وشي, :, انتهاء, علاقة, الأقران, الأندا...
# 16  [محكمة, العدل, الدولية, تأمر, إسرائيل, بالوقف,...
# 17  [بي, بي, سي, توثق, فرحة, أم, بابنها, الذي, لُق...
# 18  [تصاعد, الخلاف, بين, نتنياهو, والمؤسسة, الأمني...
# 19  [الصين, تجري, مناورات, عسكرية, ``, عقابية, '',...
# 20  [حرب, غزة, :, هل, تلتزم, إسرائيل, بقرار, محكمة...
# 21  [إقبال, كبير, على, جعة, ``, أسامة, بن, لاغر, '...
# 22  [حرب, الأجيال, في, ميانمار،, الشباب, ينتصر, عل...
# 23  [العثور, على, ملفات, حساسة, في, غرفة, نوم, ترا...
# 24  [السعودية, :, ``, لا, سلام, مع, إسرائيل, قبل, ...
# 25  [أبرز, حوادث, الطيران, التي, لقيت, فيها, شخصيا...
# 26  [ردود, فعل, متباينة, حول, اتفاق, حمدوك, مع, فص...
# 27  [``, كلما, طال, أمد, الحرب،, كلما, زادت, عزلة,...
# 28  [جدة, بريطانية, ثمانينية, تصعد, جبلاً, في, فرن...
# 29  [قوات, الدعم, السريع, في, السودان, تؤكد, استعد...
# 30  [علماء, يتوصلون, إلى, حل, للغز, بناء, أهرامات,...
# 31  [الموناليزا, :, جيولوجية, تحل, لغز, المكان, ال...
# 32  [بنوك, مودي, في, الهند, تنفق, 400, مليار, دولا...
# 33  [``, نحن, بحاجة, إلى, معجزة, '', :, الاقتصادان...
# 34  [التضخم, في, تركيا, :, ``, نحن, عالقون, بين, س...
# 35  [لماذا, يعتبر, الهواء, النقي, رفاهية, لا, يقدر...
# 36  [هل, يزعم, الغرب, أن, الصين, تنتج, فائضا, عن, ...
# 37  [قضية, أموال, ``, قذرة, '', بقيمة, ملياري, دول...
# 38  [كيف, تُصدّر, أوكرانيا, حبوبها, وما, حجمها, ال...
# 39  [شركة, يابانية, توقف, إنتاج, حفاضات, الأطفال, ...
# 40  [ماكدونالدز, تسترد, ملكية, فروع, مطاعمها, في, ...
# 41  [بريطانيا, تشهد, أكبر, ارتفاع, في, معدل, الفقر...
# 42  [المحكمة, العليا, تقضي, بعدم, جواز, قرار, منع,...
# 43  [كيف, أثرت, القيود, المفروضة, على, العملة, الأ...
# 44  [ماذا, نعرف, عن, حريق, فالنسيا, وأسبابه, المحت...
# 45  [النكبة, :, ماذا, حدث, في, 1948؟, ولماذا, يحمل...
# 46  [ماذا, يعني, تدخل, مصر, لدعم, دعوى, جنوب, أفري...
# 47  [``, بمجرد, دخولنا, على, المصابين, والأطباء, ت...
# 48  [``, إسرائيل, ستدفع, ثمن, التردد, في, اتخاذ, ا...
# 49  [عائلات, الرهائن, الإسرائيليين, تطالب, بـ, '',...
# 50  [حماس, تقول, إن, هجوم, رفح, ``, لن, يكون, نزهة...
#
#                                     lemmatized_tokens  \
# 0   [إسرائيل, تصف, قرار, المدعي, العام, بـ, ``, ال...
# 1   [إسرائيل, تعتزم, توسيع, الاجتياح, العسكري, لرف...
# 2   [انقسام, في, إسرائيل, على, خطة, إدارة, غزة, بع...
# 3   [تيك, توك, و, '', الإنسان, الأخير, '', :, لماذ...
# 4   [اليوم, العالمي, للشاي, :, أكثر, المشروبات, اس...
# 5   [ناريندرا, مودي, :, عقد, من, الشعبية, والاستقط...
# 6   [علاج, جديد, مبتكر, قد, يعالج, الشلل, الناتج, ...
# 7   [لماذا, النسيان, مفيد؟صدر, الصورة،Getty, Image...
# 8   [لماذا, يتمسك, الفلسطينيون, بالاعتراف, الأممي,...
# 9   [من, تبريز, إلى, مشهد, :, ما, خصوصية, المدن, ا...
# 10  [التعذيب, الأبيض, :, من, تزمامارت،, إيفين،, أب...
# 11  [محمد, صلاح, يلمح, إلى, البقاء, في, ليفربول, ب...
# 12  [أوضح, رئيسالمحكمة, الجنائية, الدوليةالسابق, ا...
# 13  [قال, وزير, الخارجية, الأميركيأنتوني, بلينكن-ا...
# 14  [أكدت, صحيفة, ``, واشنطن, بوست, '', اليوم, الث...
# 15  [بوتين, وشي, :, انتهاء, علاقة, الأقران, الأندا...
# 16  [محكمة, العدل, الدولية, تأمر, إسرائيل, بالوقف,...
# 17  [بي, بي, سي, توثق, فرحة, أم, بابنها, الذي, لُق...
# 18  [تصاعد, الخلاف, بين, نتنياهو, والمؤسسة, الأمني...
# 19  [الصين, تجري, مناورات, عسكرية, ``, عقابية, '',...
# 20  [حرب, غزة, :, هل, تلتزم, إسرائيل, بقرار, محكمة...
# 21  [إقبال, كبير, على, جعة, ``, أسامة, بن, لاغر, '...
# 22  [حرب, الأجيال, في, ميانمار،, الشباب, ينتصر, عل...
# 23  [العثور, على, ملفات, حساسة, في, غرفة, نوم, ترا...
# 24  [السعودية, :, ``, لا, سلام, مع, إسرائيل, قبل, ...
# 25  [أبرز, حوادث, الطيران, التي, لقيت, فيها, شخصيا...
# 26  [ردود, فعل, متباينة, حول, اتفاق, حمدوك, مع, فص...
# 27  [``, كلما, طال, أمد, الحرب،, كلما, زادت, عزلة,...
# 28  [جدة, بريطانية, ثمانينية, تصعد, جبلاً, في, فرن...
# 29  [قوات, الدعم, السريع, في, السودان, تؤكد, استعد...
# 30  [علماء, يتوصلون, إلى, حل, للغز, بناء, أهرامات,...
# 31  [الموناليزا, :, جيولوجية, تحل, لغز, المكان, ال...
# 32  [بنوك, مودي, في, الهند, تنفق, 400, مليار, دولا...
# 33  [``, نحن, بحاجة, إلى, معجزة, '', :, الاقتصادان...
# 34  [التضخم, في, تركيا, :, ``, نحن, عالقون, بين, س...
# 35  [لماذا, يعتبر, الهواء, النقي, رفاهية, لا, يقدر...
# 36  [هل, يزعم, الغرب, أن, الصين, تنتج, فائضا, عن, ...
# 37  [قضية, أموال, ``, قذرة, '', بقيمة, ملياري, دول...
# 38  [كيف, تُصدّر, أوكرانيا, حبوبها, وما, حجمها, ال...
# 39  [شركة, يابانية, توقف, إنتاج, حفاضات, الأطفال, ...
# 40  [ماكدونالدز, تسترد, ملكية, فروع, مطاعمها, في, ...
# 41  [بريطانيا, تشهد, أكبر, ارتفاع, في, معدل, الفقر...
# 42  [المحكمة, العليا, تقضي, بعدم, جواز, قرار, منع,...
# 43  [كيف, أثرت, القيود, المفروضة, على, العملة, الأ...
# 44  [ماذا, نعرف, عن, حريق, فالنسيا, وأسبابه, المحت...
# 45  [النكبة, :, ماذا, حدث, في, 1948؟, ولماذا, يحمل...
# 46  [ماذا, يعني, تدخل, مصر, لدعم, دعوى, جنوب, أفري...
# 47  [``, بمجرد, دخولنا, على, المصابين, والأطباء, ت...
# 48  [``, إسرائيل, ستدفع, ثمن, التردد, في, اتخاذ, ا...
# 49  [عائلات, الرهائن, الإسرائيليين, تطالب, بـ, '',...
# 50  [حماس, تقول, إن, هجوم, رفح, ``, لن, يكون, نزهة...
#
#                                       filtered_tokens
# 0   [إسرائيل, تصف, قرار, المدعي, العام, بـ, ``, ال...
# 1   [إسرائيل, تعتزم, توسيع, الاجتياح, العسكري, لرف...
# 2   [انقسام, إسرائيل, خطة, إدارة, غزة, الحرب،, ونت...
# 3   [تيك, توك, '', الإنسان, الأخير, '', :, لماذا, ...
# 4   [اليوم, العالمي, للشاي, :, المشروبات, استهلاكا...
# 5   [ناريندرا, مودي, :, عقد, الشعبية, والاستقطاب, ...
# 6   [علاج, جديد, مبتكر, يعالج, الشلل, الناتج, كسر,...
# 7   [لماذا, النسيان, مفيد؟صدر, الصورة،Getty, Image...
# 8   [لماذا, يتمسك, الفلسطينيون, بالاعتراف, الأممي,...
# 9   [تبريز, مشهد, :, خصوصية, المدن, تمرّ, مراسم, ت...
# 10  [التعذيب, الأبيض, :, تزمامارت،, إيفين،, أبوغري...
# 11  [محمد, صلاح, يلمح, البقاء, ليفربول, تعيين, الم...
# 12  [أوضح, رئيسالمحكمة, الجنائية, الدوليةالسابق, ا...
# 13  [قال, وزير, الخارجية, الأميركيأنتوني, بلينكن-ا...
# 14  [أكدت, صحيفة, ``, واشنطن, بوست, '', اليوم, الث...
# 15  [بوتين, وشي, :, انتهاء, علاقة, الأقران, الأندا...
# 16  [محكمة, العدل, الدولية, تأمر, إسرائيل, بالوقف,...
# 17  [سي, توثق, فرحة, بابنها, لُقب, بأصغر, رسام, ال...
# 18  [تصاعد, الخلاف, نتنياهو, والمؤسسة, الأمنية, ال...
# 19  [الصين, تجري, مناورات, عسكرية, ``, عقابية, '',...
# 20  [حرب, غزة, :, تلتزم, إسرائيل, بقرار, محكمة, ال...
# 21  [إقبال, كبير, جعة, ``, أسامة, بن, لاغر, '', حا...
# 22  [حرب, الأجيال, ميانمار،, الشباب, ينتصر, جيش, ا...
# 23  [العثور, ملفات, حساسة, غرفة, نوم, ترامب, تفتيش...
# 24  [السعودية, :, ``, سلام, إسرائيل, ضمانات, لحل, ...
# 25  [أبرز, حوادث, الطيران, لقيت, شخصيات, معروفة, م...
# 26  [ردود, فعل, متباينة, حول, اتفاق, حمدوك, فصيلين...
# 27  [``, طال, الحرب،, زادت, عزلة, إسرائيل, أصدقائه...
# 28  [جدة, بريطانية, ثمانينية, تصعد, جبلاً, فرنسا, ...
# 29  [قوات, الدعم, السريع, السودان, تؤكد, استعدادها...
# 30  [علماء, يتوصلون, حل, للغز, بناء, أهرامات, مصرص...
# 31  [الموناليزا, :, جيولوجية, تحل, لغز, المكان, رُ...
# 32  [بنوك, مودي, الهند, تنفق, 400, مليار, ليفوز, ب...
# 33  [``, بحاجة, معجزة, '', :, الاقتصادان, الإسرائي...
# 34  [التضخم, تركيا, :, ``, عالقون, سداد, بطاقة, ال...
# 35  [لماذا, يعتبر, الهواء, النقي, رفاهية, يقدر, ال...
# 36  [يزعم, الغرب, الصين, تنتج, فائضا, حاجتها, بينم...
# 37  [قضية, أموال, ``, قذرة, '', بقيمة, ملياري, تهز...
# 38  [تُصدّر, أوكرانيا, حبوبها, حجمها, الآن؟صدر, ال...
# 39  [شركة, يابانية, توقف, إنتاج, حفاضات, الأطفال, ...
# 40  [ماكدونالدز, تسترد, ملكية, فروع, مطاعمها, إسرا...
# 41  [بريطانيا, تشهد, أكبر, ارتفاع, معدل, الفقر, ال...
# 42  [المحكمة, العليا, تقضي, بعدم, جواز, قرار, منع,...
# 43  [أثرت, القيود, المفروضة, العملة, الأجنبية, سلب...
# 44  [نعرف, حريق, فالنسيا, وأسبابه, المحتملة؟صدر, ا...
# 45  [النكبة, :, حدث, 1948؟, ولماذا, يحمل, الفلسطين...
# 46  [يعني, تدخل, مصر, لدعم, دعوى, جنوب, أفريقيا, ض...
# 47  [``, بمجرد, دخولنا, المصابين, والأطباء, ترتفع,...
# 48  [``, إسرائيل, ستدفع, ثمن, التردد, اتخاذ, القرا...
# 49  [عائلات, الرهائن, الإسرائيليين, تطالب, بـ, '',...
# 50  [حماس, تقول, هجوم, رفح, ``, يكون, نزهة, '', ،,...

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(df['filtered_tokens'], df['score'], test_size=0.2, random_state=42)

# Tokenisation des textes
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# Padding des séquences
max_len = max(len(seq) for seq in X_train_seq)
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len, padding='post')

# Modèle LSTM
model = Sequential([
    Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len),
    LSTM(units=128),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entraînement du modèle
model.fit(X_train_pad, y_train, epochs=10, batch_size=32, validation_split=0.1)

# Évaluation du modèle
loss, accuracy = model.evaluate(X_test_pad, y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 462ms/step - accuracy: 0.1921 - loss: 0.6880 - val_accuracy: 0.0000e+00 - val_loss: -0.2885
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.1343 - loss: -0.1510 - val_accuracy: 0.0000e+00 - val_loss: -1.5422
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1447 - loss: -1.2023 - val_accuracy: 0.0000e+00 - val_loss: -3.8318
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.1447 - loss: -3.0670 - val_accuracy: 0.0000e+00 - val_loss: -8.8270
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1447 - loss: -7.0885 - val_accuracy: 0.0000e+00 - val_loss: -19.4654
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.1343 - loss: -16.5614 - val_accuracy: 0.0000e+00 - val_loss: -25.5747
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.1343 - loss: -21.7754 - val_accuracy: 0.0000e+00 - val_loss: -29.5815
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.1447 - loss: -25.2857 - val_accuracy: 0.0000e+00 - val_loss: -33.0772
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1447 - loss: -27.1080 - val_accuracy: 0.0000e+00 - val_loss: -36.4373
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1447 - loss: -31.3354 - val_accuracy: 0.0000e+00 - val_loss: -39.6271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0909 - loss: -37.0557
# Test Accuracy: 0.09090909361839294

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam

# Modèle LSTM pour la régression
model_regression = Sequential([
    Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len),
    LSTM(units=128),
    Dense(1)  # Pas de fonction d'activation pour la régression
])

# Utiliser une fonction de perte appropriée pour la régression (par exemple, mean squared error)
model_regression.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[MeanSquaredError(), MeanAbsoluteError()])

# Entraînement du modèle pour la régression
model_regression.fit(X_train_pad, y_train, epochs=10, batch_size=32, validation_split=0.1)

# Évaluation du modèle de régression
results = model_regression.evaluate(X_test_pad, y_test)
loss, mse, mae = results[0], results[1], results[2]

print(f'Test Loss: {loss}')
print(f'Test Mean Squared Error: {mse}')
print(f'Test Mean Absolute Error: {mae}')
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - loss: 25.7051 - mean_absolute_error: 3.8986 - mean_squared_error: 25.7051 - val_loss: 21.1681 - val_mean_absolute_error: 4.2845 - val_mean_squared_error: 21.1681
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 25.3516 - mean_absolute_error: 3.8748 - mean_squared_error: 25.3516 - val_loss: 18.8566 - val_mean_absolute_error: 3.9904 - val_mean_squared_error: 18.8566
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 21.9686 - mean_absolute_error: 3.5342 - mean_squared_error: 21.9686 - val_loss: 15.0449 - val_mean_absolute_error: 3.4248 - val_mean_squared_error: 15.0449
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 19.0670 - mean_absolute_error: 3.2990 - mean_squared_error: 19.0670 - val_loss: 9.2410 - val_mean_absolute_error: 2.5586 - val_mean_squared_error: 9.2410
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 15.6071 - mean_absolute_error: 3.1949 - mean_squared_error: 15.6071 - val_loss: 3.8647 - val_mean_absolute_error: 1.7994 - val_mean_squared_error: 3.8647
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 12.4099 - mean_absolute_error: 3.2628 - mean_squared_error: 12.4099 - val_loss: 3.3872 - val_mean_absolute_error: 1.5951 - val_mean_squared_error: 3.3872
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 12.4443 - mean_absolute_error: 3.2343 - mean_squared_error: 12.4443 - val_loss: 3.0981 - val_mean_absolute_error: 1.5631 - val_mean_squared_error: 3.0981
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 11.7877 - mean_absolute_error: 3.1747 - mean_squared_error: 11.7877 - val_loss: 2.9206 - val_mean_absolute_error: 1.5510 - val_mean_squared_error: 2.9206
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 11.0600 - mean_absolute_error: 3.0726 - mean_squared_error: 11.0600 - val_loss: 3.1362 - val_mean_absolute_error: 1.5402 - val_mean_squared_error: 3.1362
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 11.0244 - mean_absolute_error: 3.0325 - mean_squared_error: 11.0244 - val_loss: 3.5157 - val_mean_absolute_error: 1.6745 - val_mean_squared_error: 3.5157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 11.2371 - mean_absolute_error: 2.9741 - mean_squared_error: 11.2371
# Test Loss: 11.23705768585205
# Test Mean Squared Error: 11.23705768585205
# Test Mean Absolute Error: 2.97406005859375

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam

# Modèle RNN pour la régression
model_rnn = Sequential([
    Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len),
    SimpleRNN(units=128),  # Utilisation d'un RNN simple
    Dense(1)  # Pas de fonction d'activation pour la régression
])

# Utiliser une fonction de perte appropriée pour la régression (par exemple, mean squared error)
model_rnn.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[MeanSquaredError(), MeanAbsoluteError()])

# Entraînement du modèle RNN pour la régression
model_rnn.fit(X_train_pad, y_train, epochs=10, batch_size=32, validation_split=0.1)

# Évaluation du modèle RNN de régression
results_rnn = model_rnn.evaluate(X_test_pad, y_test)
loss_rnn, mse_rnn, mae_rnn = results_rnn[0], results_rnn[1], results_rnn[2]

print(f'Test Loss (RNN): {loss_rnn}')
print(f'Test Mean Squared Error (RNN): {mse_rnn}')
print(f'Test Mean Absolute Error (RNN): {mae_rnn}')
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - loss: 25.7555 - mean_absolute_error: 3.9305 - mean_squared_error: 25.7555 - val_loss: 17.3340 - val_mean_absolute_error: 3.8054 - val_mean_squared_error: 17.3340
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 19.9604 - mean_absolute_error: 3.3353 - mean_squared_error: 19.9604 - val_loss: 16.4268 - val_mean_absolute_error: 3.5482 - val_mean_squared_error: 16.4268
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 16.3880 - mean_absolute_error: 3.0010 - mean_squared_error: 16.3880 - val_loss: 9.4266 - val_mean_absolute_error: 2.5587 - val_mean_squared_error: 9.4266
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 14.2270 - mean_absolute_error: 2.9314 - mean_squared_error: 14.2270 - val_loss: 7.4003 - val_mean_absolute_error: 2.3405 - val_mean_squared_error: 7.4003
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.5676 - mean_absolute_error: 2.7331 - mean_squared_error: 11.5676 - val_loss: 5.8605 - val_mean_absolute_error: 2.1249 - val_mean_squared_error: 5.8605
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 10.9475 - mean_absolute_error: 2.7803 - mean_squared_error: 10.9475 - val_loss: 10.5962 - val_mean_absolute_error: 2.6177 - val_mean_squared_error: 10.5962
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 11.4687 - mean_absolute_error: 2.8894 - mean_squared_error: 11.4687 - val_loss: 7.9079 - val_mean_absolute_error: 2.3393 - val_mean_squared_error: 7.9079
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.8240 - mean_absolute_error: 2.6033 - mean_squared_error: 8.8240 - val_loss: 9.6904 - val_mean_absolute_error: 2.4634 - val_mean_squared_error: 9.6904
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.9047 - mean_absolute_error: 2.2918 - mean_squared_error: 7.9047 - val_loss: 14.2067 - val_mean_absolute_error: 3.4034 - val_mean_squared_error: 14.2067
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.6146 - mean_absolute_error: 2.7040 - mean_squared_error: 11.6146 - val_loss: 13.1197 - val_mean_absolute_error: 2.9412 - val_mean_squared_error: 13.1197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 13.9188 - mean_absolute_error: 2.9938 - mean_squared_error: 13.9188
# Test Loss (RNN): 13.918798446655273
# Test Mean Squared Error (RNN): 13.918798446655273
# Test Mean Absolute Error (RNN): 2.9938201904296875

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense
from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.optimizers import Adam

# Modèle Bidirectional RNN avec GRU pour la régression
model_bidirectional_gru = Sequential([
    Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len),
    Bidirectional(GRU(units=128)),  # Utilisation d'une couche Bidirectional GRU
    Dense(1)  # Pas de fonction d'activation pour la régression
])

# Utiliser une fonction de perte appropriée pour la régression (par exemple, mean squared error)
model_bidirectional_gru.compile(optimizer=Adam(), loss='mean_squared_error', metrics=[MeanSquaredError(), MeanAbsoluteError()])

# Entraînement du modèle Bidirectional RNN avec GRU pour la régression
model_bidirectional_gru.fit(X_train_pad, y_train, epochs=10, batch_size=32, validation_split=0.1)

# Évaluation du modèle Bidirectional RNN avec GRU de régression
results_bidirectional_gru = model_bidirectional_gru.evaluate(X_test_pad, y_test)
loss_bidirectional_gru, mse_bidirectional_gru, mae_bidirectional_gru = results_bidirectional_gru[0], results_bidirectional_gru[1], results_bidirectional_gru[2]

print(f'Test Loss (Bidirectional RNN with GRU): {loss_bidirectional_gru}')
print(f'Test Mean Squared Error (Bidirectional RNN with GRU): {mse_bidirectional_gru}')
print(f'Test Mean Absolute Error (Bidirectional RNN with GRU): {mae_bidirectional_gru}')
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 591ms/step - loss: 26.5230 - mean_absolute_error: 3.9531 - mean_squared_error: 26.5230 - val_loss: 21.2764 - val_mean_absolute_error: 4.3022 - val_mean_squared_error: 21.2764
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 25.1625 - mean_absolute_error: 3.8315 - mean_squared_error: 25.1625 - val_loss: 19.4729 - val_mean_absolute_error: 4.0868 - val_mean_squared_error: 19.4729
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 22.8842 - mean_absolute_error: 3.6242 - mean_squared_error: 22.8842 - val_loss: 17.1179 - val_mean_absolute_error: 3.7856 - val_mean_squared_error: 17.1179
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 21.6228 - mean_absolute_error: 3.5061 - mean_squared_error: 21.6228 - val_loss: 13.9927 - val_mean_absolute_error: 3.3402 - val_mean_squared_error: 13.9927
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 19.1653 - mean_absolute_error: 3.3129 - mean_squared_error: 19.1653 - val_loss: 10.1120 - val_mean_absolute_error: 2.6730 - val_mean_squared_error: 10.1120
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 14.8280 - mean_absolute_error: 2.9355 - mean_squared_error: 14.8280 - val_loss: 5.7944 - val_mean_absolute_error: 2.1109 - val_mean_squared_error: 5.7944
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 11.9210 - mean_absolute_error: 2.9117 - mean_squared_error: 11.9210 - val_loss: 4.4526 - val_mean_absolute_error: 1.8671 - val_mean_squared_error: 4.4526
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 13.0505 - mean_absolute_error: 3.2561 - mean_squared_error: 13.0505 - val_loss: 4.6115 - val_mean_absolute_error: 1.8017 - val_mean_squared_error: 4.6115
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 13.0279 - mean_absolute_error: 3.2014 - mean_squared_error: 13.0279 - val_loss: 3.4504 - val_mean_absolute_error: 1.6572 - val_mean_squared_error: 3.4504
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 10.7025 - mean_absolute_error: 3.0029 - mean_squared_error: 10.7025 - val_loss: 4.2590 - val_mean_absolute_error: 1.8346 - val_mean_squared_error: 4.2590
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11.0373 - mean_absolute_error: 2.8807 - mean_squared_error: 11.0373
# Test Loss (Bidirectional RNN with GRU): 11.037271499633789
# Test Mean Squared Error (Bidirectional RNN with GRU): 11.037271499633789
# Test Mean Absolute Error (Bidirectional RNN with GRU): 2.880682945251465

# %% [markdown]
# ## Performance Evaluation of Models
# #### In summary, the LSTM and Bidirectional RNN models with GRU showed better performance in predicting continuous values compared to the simpler RNN model. The slight differences in performance metrics between these models highlight the importance of model architecture and complexity in regression tasks.
